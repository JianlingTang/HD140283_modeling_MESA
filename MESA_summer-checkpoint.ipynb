# %%
import numpy as np
import matplotlib.pyplot as plt
#analyse dat file 
a_1_6 = 'ZAMS_1_6.data'
a_1_9 = 'ZAMS_a1_9.data'
a_2_3 = 'ZAMS_a2_3.data'
model_number, star_age, Teff_a_1_6, L_a_1_6= np.loadtxt(a_1_6, usecols=(0,2,37,38), unpack=True, skiprows=6)
model_number, star_age, Teff_a_1_9, L_a_1_9= np.loadtxt(a_1_9, usecols=(0,2,37,38), unpack=True, skiprows=6)
model_number, star_age, Teff_a_2_3, L_a_2_3= np.loadtxt(a_2_3, usecols=(0,2,37,38), unpack=True, skiprows=6)
star_age = star_age/1e9
plt.plot(Teff_a_1_6, L_a_1_6, "go", markersize=3, label='HR diagram for a_MLT =1.6')
plt.plot(Teff_a_1_9, L_a_1_9, "ro", markersize=3, label='HR diagram for a_MLT =1.9')
#plt.plot(Teff_a_2_3, L_a_2_3, "bo", markersize=3, label='HR diagram for a_MLT =2.3')

plt.xlabel("log Teff(K)")
plt.ylabel("log L($erg s^{-1}$)")
#plt.ylim(0.3,3.5)
plt.gca().invert_xaxis()
plt.legend(loc=2, fontsize=14)
plt.title('HR diagram of ZAMS sun')
plt.show()

# %%
#analyse dat file 
a_1_6 = 'ZAMS_1_6.data'
a_1_9 = 'ZAMS_a1_9.data'
a_2_3 = 'rgb_a2_3.data'
model_number, star_age_1_6, Teff_a_1_6, L_a_1_6= np.loadtxt(a_1_6, usecols=(0,2,37,38), unpack=True, skiprows=6)
model_number, star_age_1_9, Teff_a_1_9, L_a_1_9= np.loadtxt(a_1_9, usecols=(0,2,37,38), unpack=True, skiprows=6)
model_number, star_age_2_3, Teff_a_2_3, L_a_2_3= np.loadtxt(a_2_3, usecols=(0,2,37,38), unpack=True, skiprows=6)
star_age = star_age/1e9
#plt.plot(Teff_a_1_6, L_a_1_6, "go", markersize=3, label='HR diagram for a_MLT =1.6')
#plt.plot(Teff_a_1_9, L_a_1_9, "ro", markersize=3, label='HR diagram for a_MLT =1.9')

#plt.plot(Teff_a_2_3, L_a_2_3, "bo", markersize=3, label='HR diagram for a_MLT =2.3')




def filter_age(T,L,star_age):
    Teff_real = []
    L_real = []
    for i in range(len(star_age)):
        if star_age[i]>2.6e7:
            Teff_real.append(T[i])
            L_real.append(L[i])
    plt.plot(Teff_real, L_real, "bo", markersize=3, label='HR diagram for a_MLT =2.3')
    plt.xlabel("log Teff(K)")
    plt.ylabel("log L($erg s^{-1}$)")
    plt.gca().invert_xaxis()
    plt.legend(loc=2, fontsize=14)
    plt.title('HR diagram of ZAMS sun')
    plt.show()
            
        
filter_age(Teff_a_2_3,L_a_2_3,star_age_2_3)

# %%
a1 = 'ZAMS_mass0.7000_a1.9_Z0.0140_his.data'
a2 = 'ZAMS_mass0.7000_a1.9_Z0.0200_his.data'
a3 = 'ZAMS_mass1.0000_a1.9_Z0.0140_his.data'
model_number, star_age_1_6, Teff_a_1_6, L_a_1_6= np.loadtxt(a1, usecols=(0,2,37,38), unpack=True, skiprows=6)
model_number, star_age_1_9, Teff_a_1_9, L_a_1_9= np.loadtxt(a2, usecols=(0,2,37,38), unpack=True, skiprows=6)
model_number, star_age, Teff_a_2_3, L_a_2_3= np.loadtxt(a3, usecols=(0,2,37,38), unpack=True, skiprows=6)
star_age = star_age/1e9
plt.plot(Teff_a_1_6, L_a_1_6, "go", markersize=3, label='HR diagram for a_MLT =1.6')
plt.plot(Teff_a_1_9, L_a_1_9, "ro", markersize=3, label='HR diagram for a_MLT =1.9')
#plt.plot(Teff_a_2_3, L_a_2_3, "bo", markersize=3, label='HR diagram for a_MLT =2.3')

plt.xlabel("log Teff(K)")
plt.ylabel("log L($erg s^{-1}$)")
#plt.ylim(0.3,3.5)
plt.gca().invert_xaxis()
plt.legend(loc=2, fontsize=14)
plt.title('HR diagram of ZAMS sun')
plt.show()

# %%
#we only need to look after 0.02Gyr in the HR diagram
def filter_age(T,L,star_age):
    Teff_real = []
    L_real = []
    for i in range(len(star_age)):
        if star_age[i]>1e7:
            Teff_real.append(T[i])
            L_real.append(L[i])
    plt.plot(Teff_real, L_real, "bo", markersize=3, label='HR diagram ')
    plt.xlabel("log Teff(K)")
    plt.ylabel("log L($erg s^{-1}$)")
    plt.gca().invert_xaxis()
    plt.legend(loc=2, fontsize=14)
    plt.title('HR diagram of ZAMS sun')
    plt.show()
            
        
filter_age(Teff_a_1_6,L_a_1_6,star_age_1_6)   
        
filter_age(Teff_a_1_9,L_a_1_9,star_age_1_9)

# %%
import numpy as np
import matplotlib.pyplot as plt
def plot_HR(name):
    a = name
    model_number, star_age, Teff, L= np.loadtxt(a, usecols=(0,2,37,38), unpack=True, skiprows=6)
    plt.plot(Teff, L, "bo", markersize=3, label='HR diagram')
    plt.xlabel("log Teff(K)")
    plt.ylabel("log L($erg s^{-1}$)")
    plt.gca().invert_xaxis()
    plt.legend(loc=2, fontsize=14)
    plt.title('HR diagram of the sun')


plot_HR('ZAMS_mass1.0000_a1.9_Z0.0140_his.data')

# %%
#Bokeh file 
import numpy as np
import pandas as pd
import bokeh
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure, show, output_file 

MESA_file = 'ZAMS_mass1.0000_a1.9_Z0.0140_his.data' 

model_number, star_age, log_Teff, log_L= np.loadtxt(MESA_file, usecols=(0,2,37,38), unpack=True, skiprows=6)



star_age = star_age/1e9
model_number = model_number
star_age = star_age
log_Teff = log_Teff
log_L = log_L


## the dictionary
star_features ={'star_age': star_age,'model_number': model_number, 'log_Teff': log_Teff,'log_L': log_L}

df = pd.DataFrame(data=star_features)
source = ColumnDataSource(data=df)

TITLE = "Interactive HR"
TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,"

p = figure(tools=TOOLS, toolbar_location="above", plot_width=600, plot_height=800, title=TITLE)
p.toolbar.logo = "grey"
p.background_fill_color = "#dddddd"
p.xaxis.axis_label = "log Teff"
p.yaxis.axis_label = "log L"
p.grid.grid_line_color = "white"

## the labels 
p.hover.tooltips = [
    ("star age (Gyr):", "@star_age"),
    ]

p.circle('log_Teff', 'log_L', size=5, source = source, 
         color='green',  fill_alpha=0.8) #line_color="black",
p.x_range.flipped = True

output_file("HR.html", title="Bokeh HR plot example")#, mode='inline')
show(p)

# %%
import glob, os
os.chdir("C:/Users/tangj/Desktop/MESA_his")
track= []
for file in glob.glob("sun_mass*"):
    track.append(file)
    print(file)
# Out:
# sun_mass1.0000_a1.9_Z0.0140_his.data
# sun_mass1.0000_a1.9_Z0.0200_his.data
# sun_mass2.0000_a1.9_Z0.0140_his.data
# sun_mass2.0000_a1.9_Z0.0200_his.data
# sun_mass2.5000_a1.9_Z0.0140_his.data
# sun_mass2.5000_a1.9_Z0.0200_his.data

# %%
model_number, star_age, Teff, L= np.loadtxt(track[0], usecols=(0,2,37,38), unpack=True, skiprows=6)
Teff_2, L_2= np.loadtxt(track[1], usecols=(37,38), unpack=True, skiprows=6)

plt.plot(Teff, L, "bo-", markersize=3, label='mass=1,z=0.014')
plt.plot(Teff_2, L_2, "ro-", markersize=3, label='mass=1,z=0.02')
plt.xlabel("log Teff(K)")
plt.ylabel("log L($erg s^{-1}$)")
plt.gca().invert_xaxis()
plt.legend(loc=2, fontsize=14)
plt.title('HR diagram of the sun')
# Out:
# Text(0.5, 1.0, 'HR diagram of the sun')

# %%
Teff_3, L_3= np.loadtxt(track[2], usecols=(37,38), unpack=True, skiprows=6)
Teff_4, L_4= np.loadtxt(track[3], usecols=(37,38), unpack=True, skiprows=6)
plt.plot(Teff_3, L_3, "ro", markersize=3, label='mass=2,z=0.014')
plt.plot(Teff_4, L_4, "go", markersize=3, label='mass=2,z=0.020')
plt.xlabel("log Teff(K)")
plt.ylabel("log L($erg s^{-1}$)")
plt.gca().invert_xaxis()
plt.legend(loc=2, fontsize=14)
plt.title('HR diagram of the 2M_sun')
# Out:
# Text(0.5, 1.0, 'HR diagram of the 2M_sun')

# %%
Teff_3, L_3= np.loadtxt(track[4], usecols=(37,38), unpack=True, skiprows=6)
Teff_4, L_4= np.loadtxt(track[5], usecols=(37,38), unpack=True, skiprows=6)
plt.plot(Teff_3, L_3, "ro", markersize=3, label='mass=2.5,z=0.014')
plt.plot(Teff_4, L_4, "go", markersize=3, label='mass=2.5,z=0.020')
plt.xlabel("log Teff(K)")
plt.ylabel("log L($erg s^{-1}$)")
plt.gca().invert_xaxis()
plt.legend(loc=2, fontsize=14)
plt.title('HR diagram of the 2.2M_sun')
# Out:
# Text(0.5, 1.0, 'HR diagram of the 2.2M_sun')

# %%
Teff_3, L_3= np.loadtxt(track[4], usecols=(37,38), unpack=True, skiprows=6)
Teff_4, L_4= np.loadtxt(track[5], usecols=(37,38), unpack=True, skiprows=6)
plt.plot(Teff_3, L_3, "ro", markersize=3, label='mass=2.5,z=0.014')
plt.plot(Teff_4, L_4, "go", markersize=3, label='mass=2.5,z=0.020')
plt.xlabel("log Teff(K)")
plt.ylabel("log L($erg s^{-1}$)")
plt.gca().invert_xaxis()
plt.legend(loc=2, fontsize=14)
plt.title('HR diagram of the 2.2M_sun')
# Out:
# Text(0.5, 1.0, 'HR diagram of the 2.2M_sun')

# %% [markdown]
# # Medium resolution HR diagram

# %%
import glob, os
os.chdir("C:/Users/tangj/Desktop/MESA_his")
track= []
for file in glob.glob("sun_med*"):
    track.append(file)
    print(file)
# Out:
# sun_med_resolution_mass1.0000_a1.9_Z0.0140_his.data
# sun_med_resolution_mass1.0000_a1.9_Z0.0200_his.data
# sun_med_resolution_mass2.0000_a1.9_Z0.0140_his.data
# sun_med_resolution_mass2.0000_a1.9_Z0.0200_his.data
# sun_med_resolution_mass2.5000_a1.9_Z0.0140_his.data
# sun_med_resolution_mass2.5000_a1.9_Z0.0200_his.data

# %%
model_number, star_age, Teff, L= np.loadtxt(track[0], usecols=(0,2,37,38), unpack=True, skiprows=6)
Teff_2, L_2= np.loadtxt(track[1], usecols=(37,38), unpack=True, skiprows=6)

plt.plot(Teff, L, "bo-", markersize=3, label='mass=1,z=0.014')
plt.plot(Teff_2, L_2, "ro-", markersize=3, label='mass=1,z=0.02')
plt.xlabel("log Teff(K)")
plt.ylabel("log L($erg s^{-1}$)")
plt.gca().invert_xaxis()
plt.legend(loc=2, fontsize=14)
plt.title('HR diagram of the sun')
# Out:
# Text(0.5, 1.0, 'HR diagram of the sun')

# %%
Teff_3, L_3= np.loadtxt(track[2], usecols=(37,38), unpack=True, skiprows=6)
Teff_4, L_4= np.loadtxt(track[3], usecols=(37,38), unpack=True, skiprows=6)
plt.plot(Teff_3, L_3, "ro", markersize=3, label='mass=2,z=0.014')
plt.plot(Teff_4, L_4, "go", markersize=3, label='mass=2,z=0.020')
plt.xlabel("log Teff(K)")
plt.ylabel("log L($erg s^{-1}$)")
plt.gca().invert_xaxis()
plt.legend(loc=2, fontsize=14)
plt.title('HR diagram of the 2M_sun')
# Out:
# Text(0.5, 1.0, 'HR diagram of the 2M_sun')

# %%
Teff_3, L_3= np.loadtxt(track[4], usecols=(37,38), unpack=True, skiprows=6)
Teff_4, L_4= np.loadtxt(track[5], usecols=(37,38), unpack=True, skiprows=6)
plt.plot(Teff_3, L_3, "ro-", markersize=3, label='mass=2.5,z=0.014')
plt.plot(Teff_4, L_4, "go-", markersize=3, label='mass=2.5,z=0.020')
plt.xlabel("log Teff(K)")
plt.ylabel("log L($erg s^{-1}$)")
plt.gca().invert_xaxis()
plt.legend(loc=2, fontsize=14)
plt.title('HR diagram of the 2.5M_sun')
# Out:
# Text(0.5, 1.0, 'HR diagram of the 2.5M_sun')

# %% [markdown]
# ## BASH_LOOPER FOR LOOPS

# %% [markdown]
# import time
# outfile = open('execution_time_janett.txt',"a")
# for i in range(len(alpha)):
#     a = alpha[i]
#     for j in range(len(masses)):
#         m = masses[j]
#         for v in range(len(Z_in)):
#             z = Z_in[v]
#             for w in range(len(Y_in)):
#                 y= Y_in[v]
#                 start_time = time.time()
#                 subprocess.call(r"cp " + template_inlist_name+ " "          + new_inlist_name, shell=True)
#                 subprocess.call(r"sed -i 's/<<MASS>>/"+         ffmt(m)+"/g' "      + new_inlist_name, shell=True)
#                 subprocess.call(r"sed -i 's/<<METALLICITY>>/"+         ffmt(z)+"/g' "      + new_inlist_name, shell=True)
#                 subprocess.call(r"sed -i 's/<<ALPHA>>/" +ffmt(age) +"/g' " +new_inlist_name, shell=True)
#                 subprocess.call(r"sed -i 's/<<HELIUM>>/" +ffmt(age) +"/g' " +new_inlist_name, shell=True)
#                 subprocess.call("\
#                                     export MESA_DIR=/avatar/janett/MESA/mesa-r12778; \
#                                     export MESASDK_ROOT=/avatar/janett/MESA/mesasdk; \
#                                     source $MESASDK_ROOT/bin/mesasdk_init.sh; \
#                                     ./rn", shell=True)
#                 runtime(time.time() - start_time)
#                 with open('executiontime_janet.txt',"a") as f:
#                     f.write("execution time equals: "+str(runtime)+ '\n')
#
#                     f.write("mass ="+str(m) +'\n')
#
#                     f.write("metallicity :"+str(z)+'\n')
#
#                     f.write("helium mass fraction :"+str(y)+'\n')
#
#                     f.write("mixing length alpha: "+str(a)+'\n')
# outfile.close()

# %% [markdown]
# # TESTING WRITE() IO COMMAND

# %%
runtime = 1
m=1
y=3
z=3
a=2



with open('execution.txt',"a") as f:
    f.write("execution time equals: "+str(runtime)+ '\n')

    f.write("mass ="+str(m) +'\n')

    f.write("metallicity :"+str(z)+'\n')

    f.write("helium mass fraction :"+str(y)+'\n')

    f.write("mixing length alpha: "+str(a)+'\n')

# %% [markdown]
# ## DATA PLOTTING

# %% [markdown]
# ### plotting functions pre-defined

# %%
def plot_HR(file):
    from matplotlib.pyplot import figure
    figure(num=None, figsize=(7, 5.5), dpi=100, facecolor='w', edgecolor='k')
    for fname in file:
        model_number, star_age, log_LH,log_Teff, log_L= np.loadtxt(fname, usecols=(0,2,16,37,38), unpack=True, skiprows=6)
        ratio = 10**log_LH/10**log_L
        T_eff_r = []
        L_r = []                                      
        #filter criteria ratio = 0.999
        for i in range(len(log_LH)):
            if ratio[i] >=0.999:
                T_eff_r.append(10**log_Teff[i])
                L_r.append(10**log_L[i])
        plt.plot(T_eff_r,L_r, markersize=3,label=str(fname))
        plt.xlabel("Teff(K)")
        plt.ylabel("$L_{\odot}$")
        plt.legend()
    plt.title('m1.1')
    plt.gca().invert_xaxis()   
    plt.gca().add_patch(Rectangle((5443,4.07),100,1,linewidth=1,edgecolor='r',facecolor='None'))

def plot_box(file,name_mass):
    from matplotlib.pyplot import figure
    figure(num=None, figsize=(7, 5.5), dpi=100, facecolor='w', edgecolor='k')
    for fname in file:
        model_number, star_age, log_LH,log_Teff, log_L= np.loadtxt(fname, usecols=(0,2,16,37,38), unpack=True, skiprows=6)
        ratio = log_LH/log_L
        T_eff_r = []
        L_r = []                                      
        #filter criteria ratio = 0.999
        for i in range(len(log_LH)):
            if ratio[i] >=0.999:
                T_eff_r.append(10**log_Teff[i])
                L_r.append(10**log_L[i])
        plt.plot(T_eff_r,L_r, markersize=3)
        plt.xlabel("log Teff(K)")
        plt.ylabel("$log L$")
        plt.title(name_mass)  
    plt.gca().add_patch(Rectangle((5443,4.07),100,1,linewidth=1,edgecolor='r',facecolor='None'))

#####
#plt.ylim(4,4.2)
#plt.xlim(5400,6500)
#plt.text(6500, 4.175, 'box intersecting with m=0.7,0.8,0.7 M_sun',
#verticalalignment='bottom', horizontalalignment='right',color='r',fontsize=13)
####

# %%
import glob, os
os.chdir("C:/Users/tangj/Desktop/MESA_his")
track= []
file = glob.glob("m1.1*z0.014*y0.3*")
file
# Out:
# ['m1.1000z0.0140y0.3000a1.5000_his.data',
#  'm1.1000z0.0140y0.3000a1.5500_his.data',
#  'm1.1000z0.0140y0.3000a1.6000_his.data',
#  'm1.1000z0.0140y0.3000a1.6500_his.data',
#  'm1.1000z0.0140y0.3000a1.7000_his.data',
#  'm1.1000z0.0140y0.3000a1.7500_his.data',
#  'm1.1000z0.0140y0.3000a1.8000_his.data',
#  'm1.1000z0.0140y0.3000a1.8500_his.data',
#  'm1.1000z0.0140y0.3000a1.9000_his.data',
#  'm1.1000z0.0140y0.3000a1.9500_his.data']

# %%
#plotting multiple files in the same graph
def plot_HR(file):
    from matplotlib.pyplot import figure
    figure(num=None, figsize=(7, 5.5), dpi=100, facecolor='w', edgecolor='k')
    for fname in file:
        model_number, star_age, log_LH,log_Teff, log_L= np.loadtxt(fname, usecols=(0,2,16,37,38), unpack=True, skiprows=6)
        ratio = 10**log_LH/10**log_L
        T_eff_r = []
        L_r = []                                      
        #filter criteria ratio = 0.999
        for i in range(len(log_LH)):
            if ratio[i] >=0.999:
                T_eff_r.append(10**log_Teff[i])
                L_r.append(10**log_L[i])
        fl=list(fname)
        s1=''.join(fl[7:26])
        plt.plot(T_eff_r,L_r, markersize=3,label=str(fname))
        plt.xlabel("Teff(K)")
        plt.ylabel("$L_{\odot}$")
        plt.legend()
    plt.title('m1.1')
    plt.gca().invert_xaxis()   
    plt.gca().add_patch(Rectangle((5443,4.07),100,1,linewidth=1,edgecolor='r',facecolor='None'))

# %%
def plot_box(file):
    n=len(file)
    color=cm.rainbow(np.linspace(0,1,n))
    fig = plt.figure()
    ax = plt.subplot(111)

    for i,c in zip(range(len((file))),color):
        model_number, star_age, log_LH,log_Teff, log_L= np.loadtxt(file[i], usecols=(0,2,16,37,38), unpack=True, skiprows=6)
        ratio = 10**log_LH/10**log_L
        T_eff_r = []
        L_r = []                                      
    #filter criteria ratio = 0.999
        for j in range(len(log_LH)):
            if ratio[j] >=0.999:
                T_eff_r.append(10**log_Teff[j])
                L_r.append(10**log_L[j])
        fl=list(file[i])
        s1=''.join(fl[:26])
        plt.plot(T_eff_r,L_r, markersize=3,label=s1,c=c)
        plt.xlabel("Teff(K)")
        plt.ylabel("$L_{\odot}$")
        plt.title(name_HR)
        plt.gca().add_patch(Rectangle((5443,4.07),100,1,linewidth=1,edgecolor='r',facecolor='grey'))

# %%
plot_box(file)
plt.legend(bbox_to_anchor=(1.2, 1.25), ncol=3,handleheight=2.4, labelspacing=0.05)  
plt.ylim(4,4.25)
plt.xlim(5400,5600)
plt.text(5600, 4.3, 'box intersecting with z0.014;y=0.3;a=1.5-1.65',
verticalalignment='bottom', horizontalalignment='right',color='r',fontsize=13)
plt.show()

# %% [markdown]
# ## select text from string
# file = glob.glob("m1.20*")
# fl=list(file[1])
# s1=''.join(fl[7:26])

# %%
n=40
color=cm.rainbow(np.linspace(0,1,n))
fig = plt.figure()
ax = plt.subplot(111)
file = glob.glob("m1.2*")

for i,c in zip(range(len((file))),color):
    model_number, star_age, log_LH,log_Teff, log_L= np.loadtxt(file[i], usecols=(0,2,16,37,38), unpack=True, skiprows=6)
    ratio = 10**log_LH/10**log_L
    T_eff_r = []
    L_r = []                                      
    #filter criteria ratio = 0.999
    for j in range(len(log_LH)):
        if ratio[j] >=0.999:
            T_eff_r.append(10**log_Teff[j])
            L_r.append(10**log_L[j])
    fl=list(file[i])
    s1=''.join(fl[7:26])
    plt.plot(T_eff_r,L_r, markersize=3,label=s1,c=c)
    plt.xlabel("Teff(K)")
    plt.ylabel("$L_{\odot}$")
    plt.legend()
    plt.title(name_HR)
    plt.gca().invert_xaxis()   
    plt.gca().add_patch(Rectangle((5443,4.07),100,1,linewidth=1,edgecolor='r',facecolor='grey'))
    
    ax.legend(bbox_to_anchor=(1.1, 1.05), ncol=4,handleheight=2.4, labelspacing=0.05)
    
    plt.xlim(5400,5600)
    plt.text(5800, 5.75, 'box intersecting with z0.014/0.02;y=0.3;a=1.5-1.95',
    verticalalignment='bottom', horizontalalignment='right',color='r',fontsize=13)

# %%
def plot_box(file,name):
    n=len(file)
    color=cm.rainbow(np.linspace(0,1,n))
    fig = plt.figure()
    ax = plt.subplot(111)

    for i,c in zip(range(len((file))),color):
        model_number, star_age, log_LH,log_Teff, log_L= np.loadtxt(file[i], usecols=(0,2,16,37,38), unpack=True, skiprows=6)
        ratio = 10**log_LH/10**log_L
        T_eff_r = []
        L_r = []                                      
    #filter criteria ratio = 0.999
        for j in range(len(log_LH)):
            if ratio[j] >=0.999:
                T_eff_r.append(10**log_Teff[j])
                L_r.append(10**log_L[j])
        fl=list(file[i])
        s1=''.join(fl[:26])
        plt.plot(T_eff_r,L_r, markersize=3,label=s1,c=c)
        plt.xlabel("Teff(K)")
        plt.ylabel("$L_{\odot}$")
        plt.title(name)
        plt.gca().add_patch(Rectangle((5443,4.07),100,1,linewidth=1,edgecolor='r',facecolor='grey'))
    
file = glob.glob("m1.2*z0.0200y0.3*")
len(file)
figure(num=None, figsize=(7, 5.5), dpi=100, facecolor='w', edgecolor='k')
plot_box(file,'HR diagram of m=1.2 M_sun')
plt.legend(bbox_to_anchor=(1, 1.45), ncol=2,handleheight=1, labelspacing=0.03)  
plt.ylim(3.5,5.5)
plt.xlim(5400,5600)
plt.show()

# %%
file = glob.glob("m1.2*z0.014*y0.3*")
figure(num=None, figsize=(7, 5.5), dpi=100, facecolor='w', edgecolor='k')
plot_box(file,'HR diagram of m=1.2 M_sun')
plt.legend(bbox_to_anchor=(1, 1.45), ncol=2,handleheight=1, labelspacing=0.03)  
plt.ylim(3.5,5.5)
plt.xlim(5400,5600)
plt.show()

# %%
file = glob.glob("m1.3*z0.0200y0.3*")

# %%
figure(num=None, figsize=(7, 5.5), dpi=100, facecolor='w', edgecolor='k')
plot_box(file,'HR diagram of m=1.3 M_sun')
plt.legend(bbox_to_anchor=(1, 1.5), ncol=2,handleheight=1, labelspacing=0.03)  
plt.ylim(3.5,5.5)
plt.xlim(5400,5600)
plt.show()

# %% [markdown]
# 0.4 doesn't work, super solar value/enhanced helium abundance
# super-solar values of helium (Y) or "enhanced helium abundance" were not a good fit, formation side, the star is not born in a enhanced helium abundance environment.

# %%
file = glob.glob("m*z*y*_his.data")
file
#np.max function ...
#z= 0.014 what is the max and min for being in the box?
#define one test case.four point relation/extreme points/ boundaries
# Out:
# ['m0.7000z0.0140y0.3000a1.5000_his.data',
#  'm0.7000z0.0140y0.3000a1.5500_his.data',
#  'm0.7000z0.0140y0.3000a1.6000_his.data',
#  'm0.7000z0.0140y0.3000a1.6500_his.data',
#  'm0.7000z0.0140y0.3000a1.7000_his.data',
#  'm0.7000z0.0140y0.3000a1.7500_his.data',
#  'm0.7000z0.0140y0.3000a1.8000_his.data',
#  'm0.7000z0.0140y0.3000a1.8500_his.data',
#  'm0.7000z0.0140y0.3000a1.9000_his.data',
#  'm0.7000z0.0140y0.3000a1.9500_his.data',
#  'm0.7000z0.0140y0.4000a1.5000_his.data',
#  'm0.7000z0.0140y0.4000a1.5500_his.data',
#  'm0.7000z0.0140y0.4000a1.6000_his.data',
#  'm0.7000z0.0140y0.4000a1.6500_his.data',
#  'm0.7000z0.0140y0.4000a1.7000_his.data',
#  'm0.7000z0.0140y0.4000a1.7500_his.data',
#  'm0.7000z0.0140y0.4000a1.8000_his.data',
#  'm0.7000z0.0140y0.4000a1.8500_his.data',
#  'm0.7000z0.0140y0.4000a1.9000_his.data',
#  'm0.7000z0.0140y0.4000a1.9500_his.data',
#  'm0.7000z0.0200y0.3000a1.5000_his.data',
#  'm0.7000z0.0200y0.3000a1.5500_his.data',
# ...

# %%
def plot_HR(file,name):
    figure(num=None, figsize=(7, 5.5), dpi=100, facecolor='w', edgecolor='k')
    n=len(file)
    color=cm.rainbow(np.linspace(0,1,n))
    fig = plt.figure()
    ax = plt.subplot(111)
    
    for i,c in zip(range(len((file))),color):
        model_number, star_age, log_LH,log_Teff, log_L= np.loadtxt(file[i], usecols=(0,2,16,37,38), unpack=True, skiprows=6)
        ratio = 10**log_LH/10**log_L
        T_eff_r = []
        L_r = []                                      
    #filter criteria ratio = 0.999
        for j in range(len(log_LH)):
            if ratio[j] >=0.999:
                T_eff_r.append(10**log_Teff[j])
                L_r.append(10**log_L[j])
        fl=list(file[i])
        s1=''.join(fl[:26])
        plt.plot(T_eff_r,L_r, markersize=3,label=s1,c=c)
    plt.gca().add_patch(Rectangle((5443,4.07),100,1,linewidth=1,edgecolor='r',facecolor='grey'))
    plt.xlabel("Teff(K)")
    plt.ylabel("$L_{\odot}$")
    plt.title(name)
    plt.legend(bbox_to_anchor=(1.12, 0.3), ncol=2,handleheight=1, labelspacing=0.05)  
    ax = plt.gca()
    ax.invert_xaxis()
    plt.show()

# %%
figure(num=None, figsize=(7, 5.5), dpi=100, facecolor='w', edgecolor='k')
n=len(file)
color=cm.rainbow(np.linspace(0,1,n))
fig = plt.figure()
ax = plt.subplot(111)
name = 'gird search'    
    
for i,c in zip(range(len((file))),color):
    
    model_number, star_age, log_LH,log_Teff, log_L= np.loadtxt(file[i], usecols=(0,2,16,37,38), unpack=True, skiprows=6)
    ratio = 10**log_LH/10**log_L
    T_eff= []
    L=  []                         
    #filter criteria ratio = 0.999
    for j in range(len(log_LH)):
        if ratio[j] >0.999:
            T_eff.append(10**log_Teff[j])
            L.append(10**log_L[j])
    fl=list(file[i])
    s1=''.join(fl[:26])
    plt.plot(T_eff,L,markersize=3,label=s1,c=c)
    plt.scatter(T_eff,L,c=c)
    
plt.gca().add_patch(Rectangle((5443,4.07),100,1,linewidth=1,edgecolor='r',facecolor='grey'))
plt.xlabel("Teff(K)")
plt.ylabel("$L_{\odot}$")
plt.title(name)
plt.gca().invert_xaxis()
plt.xlim(5400,5600)
plt.ylim(3,6)
plt.legend(bbox_to_anchor=(1.12, 0.3), ncol=2,handleheight=1, labelspacing=0.05)  
plt.show()
#plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %%
zval=[]
yval=[]
mval=[]
mltval=[]
Chi_sq_lst = []
R_obs = 2.21
R_sig = 0.08
L_obs = 4.12
L_sig = 0.5
T_obs = 5543 
T_sig = 100

outfile = open('intersect_tracks.txt',"w")
outfile.write('#mass,z,y,MLT_a,T_eff,L_eff,R_eff,chi_sq_val'+"\n")
for i in range(len((file))):
    zval.append(s1.split("z")[1].split("y")[0])
    yval.append(s1.split("y")[1].split("a")[0])
    mval.append(s1.split("m")[1].split("z")[0])
    mltval.append(s1.split("a")[1].split("0")[0])
    model_number, star_age, log_LH,log_Teff, log_L,log_R= np.loadtxt(file[i], usecols=(0,2,16,37,38,39), unpack=True, skiprows=6)
    T_eff=10**log_Teff
    L=10**log_L   
    R = 10**log_R
    LH = 10**log_LH
    ratio = LH/L
    #filter criteria ratio = 0.999
    #for j in range(len(log_LH)):
        #if ratio[j] >0.999:
            #T_eff.append(10**log_Teff[j])
            #L.append(10**log_L[j])
    #T_eff_ar=np.array(T_eff)
    #L_ar = np.array(L)
    nfile=list(file[i])
    s1=''.join(nfile)
    Lobs_min = 4.07
    Lobs_max = 4.17
    T_obs_min = 5443
    T_obs_max = 5643
    
    #split..
    #The luminosity (photometry) of this star is: 4.12 +/- 0.50 Lsolar
    #Its temperature (spectroscopy) is: 5543 +/- 100 Kelvin
    indexes = np.where((L>=Lobs_min) &\
                       (L<=Lobs_max)&\
                       ( T_eff>=T_obs_min) &\
                       (T_eff<=T_obs_max) &\
                      (ratio>=0.999))[0]
    intersec_Teff = T_eff[indexes]
    intersec_L = L[indexes]
    intersec_R = R[indexes]
    T_lst = []
    L_lst = []
    R_lst = []
    if intersec_Teff.size != 0:
        for i in range(len(intersec_Teff)):
            T='%.2f' % intersec_Teff[i]
            T_lst.append(T)
            L='%.2f' % intersec_L[i]
            L_lst.append(L)
            R='%.2f' % intersec_R[i]
            R_lst.append(R)
            Chi_sq = 1/3*(((T_obs-float(T))/T_sig)**2+((L_obs-float(L))/L_sig)**2+((R_obs-float(R))/R_sig)**2)
            Chi_sq_lst.append(Chi_sq)
            Chi_sq_val = '%.2f' % Chi_sq
        
        # we need to store the values into an output file:
        with open('intersect_tracks.txt',"a") as f:
            f.write(s1.split("m")[1].split("z")[0]+"  ")
            f.write(s1.split("z")[1].split("y")[0]+"  ")

            f.write(s1.split("y")[1].split("a")[0]+"  ")

            f.write(s1.split("a")[1].split("0")[0]+"  ")
            f.write(T+"  ")
            f.write(L+"  ")
            f.write(R+"  "+"\n")
            f.write(Chi_sq_val+'\n')
            #f.write(intersec_Teff+'\n')
index_min = Chi_sq_lst.index(min(Chi_sq_lst))

# %%
print(index_min)
#we have the 2nd value in Chi_sq_lst as the minimum
# Out:
# 2

# %% [markdown]
# ### New bash_looper intervals
# def ffmt(n):
#         return "%1.4f"%n
#
# #needs to have <<FEATURES>>
# run_full_grid = False
#
# if run_full_grid:
#     masses = np.arange(0.6,1.2,0.1)
#     Z_in =np.arange(0.003,0.015,0.001)
#     Y_in = [0.28,0.3]
#     alpha = np.arange(1.6,2.0,0.2)
# else:
#         masses =[0.6]
#         Z_in =[0.003]
#         Y_in = [0.3]
#         alpha = [1.5]
# #based on ages stopping conditions

# %%
0.0031622
0.00501187233

# %% [markdown]
# ### split() function:
# zval.append(s1.split("z")[1].split("y")[0])
#
# yval.append(s1.split("y")[1].split("a")[0])
#
# mval.append(s1.split("m")[1].split("z")[0])
#
# mltval.append(s1.split("a")[1].split("0")[0])

# %% [markdown]
# ## Combinations to be compared using chi-squared

# %% [markdown]
# ## $\begin{aligned} \frac{1}{3}s_{\text {classic }}^{2}=&\left[\frac{R{_\mathrm{obs}}-R_{ \mathrm{mod}}}{\sigma_{R, \text { obs }}}\right]^{2} \\&+\left[\frac{L{_\mathrm{obs}}-L_{ \mathrm{mod}}}{\sigma_{L, \text { obs }}}\right]^{2} \\&+\left[\frac{Z/X_{\mathrm{obs}}-{Z/X_\mathrm{mod}}}{\sigma Z/X_{\mathrm{obs}}}\right]^{2}\end{aligned}$

# %% [markdown]
# # possible combinations:
# ### m = 1.2 $M_{\odot}, z = 0.020, y =0.3, a =1.50 $ to 1.95
# ### m = 1.2 $M_{\odot}, z = 0.014, y =0.3, a =1.65 $ to 1.95
# ### m = 1.3 $M_{\odot}, z = 0.020, y =0.3, a =1.80 $ to 1.95

# %% [markdown]
# ## The luminosity (photometry) of this star is: 4.12 +/- 0.50 Lsolar
# ## radius (interferometry) is: 2.21 +/- 0.08 Rsolar
# ## surface abundance (spectroscopy) Z/X_surf is: Z/X = 0.000186 +0.0001, -0.000014 (non-uniform uncertainty)

# %%
file = glob.glob("m1.2*z0.0200y0.3*")

# %%
for i in range(len(file)):
    model_number, star_age, log_LH,log_Teff, log_L,log_R= np.loadtxt(fname, usecols=(0,2,16,37,38,39), unpack=True, skiprows=6)
    ratio = 10**log_LH/10**log_L
    T_eff_r= []
    L_r = []   
    R_r = []
#filter criteria ratio = 0.999
    for i in range(len(log_LH)):
        if ratio[i] >=0.999:
            Teff_r.append(10**log_Teff[i])
            L_r.append(10**log_L[i])
            R_r.append(10**log_R[i])
#do chi=square value :
    R_obs = 2.21
    R_sig = 0.08
    L_obs = 4.12
    L_sig = 0.5
    ZX_obs = 0.000186
    ZX_sig1 = 0.0001
    ZX_sig2 = 0.000014
    chi_sq = 4*(R_r

# %%
file = glob.glob("m0.7*z0.014*y0.3*")
file
# Out:
# ['m0.7000z0.0140y0.3000a1.5000_his.data',
#  'm0.7000z0.0140y0.3000a1.5500_his.data',
#  'm0.7000z0.0140y0.3000a1.6000_his.data',
#  'm0.7000z0.0140y0.3000a1.6500_his.data',
#  'm0.7000z0.0140y0.3000a1.7000_his.data',
#  'm0.7000z0.0140y0.3000a1.7500_his.data',
#  'm0.7000z0.0140y0.3000a1.8000_his.data',
#  'm0.7000z0.0140y0.3000a1.8500_his.data',
#  'm0.7000z0.0140y0.3000a1.9000_his.data',
#  'm0.7000z0.0140y0.3000a1.9500_his.data']

# %%
for fname in file:
    model_number, star_age, log_LH,log_Teff, log_L,log_R= np.loadtxt(fname, usecols=(0,2,16,37,38,39), unpack=True, skiprows=6)
print(sum(model_number))
# Out:
# 11204219.0

# %%
## for option (3), define variables
template_inlist_name = 'inlist_msearch_template' ## name of your template inlist

## don't worry too much about this definition, just make sure it matches the value assigned in "inlist"
new_inlist_name = 'inlist_temp' ## blank parameter; doesn't matter

import time
with open('execution.txt',"a") as f:
         for i in range(len(alpha)):
                 a = alpha[i]
                 for j in range(len(masses)):
                         m = masses[j]
                         max_age = max_ages[j]
                         for v in range(len(Z_in)):
                                 z = Z_in[v]
                                 for w in range(len(Y_in)):
                                         y= Y_in[w]
                                         files_done = glob.glob("/avatar/janett/MESA/work_solar/LOGS/m*y*his.data")
                                         f_name = 'm'+str(m)+'z'+str(z)+'y'+str(y)+'a'+str(a)+'_his.data'
                                         if f_name in files_done:
                                             continue 
                                         else:
                                             start_time = time.time()
                                             subprocess.call(r"cp " + template_inlist_name+ " "          + new_inlist_name, shell=True)
                                             subprocess.call(r"sed -i 's/<<MASS>>/"+         ffmt(m)+"/g' "      + new_inlist_name, shell=True)
                                             subprocess.call(r"sed -i 's/<<MAX_AGE>>/"+         ffmt(max_age)+"/g' "      + new_inlist_name, shell=True)
                                             subprocess.call(r"sed -i 's/<<METALLICITY>>/"+         ffmt(z)+"/g' "      + new_inlist_name, shell=True)
                                             subprocess.call(r"sed -i 's/<<ALPHA>>/" +ffmt(a) +"/g' " +new_inlist_name, shell=True)
                                             subprocess.call(r"sed -i 's/<<HELIUM>>/" +ffmt(y) +"/g' " +new_inlist_name, shell=True)
                                        
                                         
                                             subprocess.call("\
                                                                export MESA_DIR=/avatar/janett/MESA/mesa-r12778; \
                                                                export MESASDK_ROOT=/avatar/janett/MESA/mesasdk; \
                                                                export OMP_NUM_THREADS =14; \
                                                                source $MESASDK_ROOT/bin/mesasdk_init.sh; \
                                                                ./rn", shell=True)
                                             runtime = time.time()-start_time
                                             f.write("execution time equals: "+str(runtime)+ '\n')
                                             f.write("mass ="+str(m) +'\n')
                                             f.write("metallicity :"+str(z)+'\n')
                                             f.write("helium mass fraction :"+str(y)+'\n')
                                             f.write("mixing length alpha: "+str(a)+'\n')
